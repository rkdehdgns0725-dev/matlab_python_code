# %%
from datetime import datetime
pr_second=-1

def print_second(num):
    pre_second=num
    while True:
        now=time.datetime.now()
        second=int(now.strftime("%S"))
        if pre_second!=second:
            print(second)
            pre_second=second
        
    

    
            
        


print_second(pr_second)
# Out:
# 33
# 34
# 35
# 36
# 37
# 38
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 20
#      10             print(second)
#      11             pre_second=second
# ---> 20 print_second(pr_second)
#
# Cell In[71], line 8, in print_second(num)
#       6 while True:
#       7     now=time.datetime.now()
# ----> 8     second=int(now.strftime("%S"))
#       9     if pre_second!=second:
#      10         print(second)
#
# KeyboardInterrupt:

# %%
from math import sin
from math import pi
print(sin(pi))
# Out:
# 1.2246467991473532e-16

# %%
a='"101호	102호201호	202호301호	302호'.replace('호','호","')
a=a.replace('	','')
print(a)
# Out:
# "101호","102호","201호","202호","301호","302호","
